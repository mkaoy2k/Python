# %% [markdown]
# # 1 Hello World

# %%
# printing my first message
print('Hello World')
# Out:
# Hello World

# %%
"Hello World"
# Out:
# 'Hello World'

# %% [markdown]
# # 2 Data Types

# %%
type(1)
# Out:
# int

# %%
type(2.4)
# Out:
# float

# %%
1 + 2
# Out:
# 3

# %%
4-1
# Out:
# 3

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
type('Hello World')
# Out:
# str

# %%
print('Hello World'.upper())
print('Hello World'.lower())
print('Hello World'.title())
# Out:
# HELLO WORLD
# hello world
# Hello World

# %%
'Hello World'.count('l')
# Out:
# 3

# %%
'Hello World'.replace('o', '0')
# Out:
# 'Hell0 W0rld'

# %% [markdown]
# # 3 Variables

# %%
message_1 = "I'm learning Python"

# %%
message_1
# Out:
# "I'm learning Python"

# %%
message_2 = "and it's fun"

# %%
message_2
# Out:
# "and it's fun"

# %%
message = message_1 + " " + message_2
message
# Out:
# "I'm learning Python and it's fun"

# %%
f'{message_1} {message_2}'
# Out:
# "I'm learning Python and it's fun"

# %% [markdown]
# # 4 List

# %%
countries = ['United States', 'India', 'Taiwan', 'Brazil']
countries
# Out:
# ['United States', 'India', 'Taiwan', 'Brazil']

# %%
# zero indexed
countries[0]
# Out:
# 'United States'

# %%
# reverse indexed
countries[-1]
# Out:
# 'Brazil'

# %%
countries[-4]
# Out:
# 'United States'

# %%
# slicing list[start:stop]
countries[0:2]
# Out:
# ['United States', 'India']

# %%
countries[1:]
# Out:
# ['India', 'Taiwan', 'Brazil']

# %%
countries[:2]
# Out:
# ['United States', 'India']

# %% [markdown]
# ## 4.1 Adding elements to a list

# %%
countries = ['United States', 'India', 'Taiwan', 'Brazil']
countries
# Out:
# ['United States', 'India', 'Taiwan', 'Brazil']

# %%
countries.append('Canada')
countries
# Out:
# ['United States', 'India', 'Taiwan', 'Brazil', 'Canada']

# %%
countries.insert(0, 'Spain')
countries
# Out:
# ['Spain', 'United States', 'India', 'Taiwan', 'Brazil', 'Canada']

# %%
countries_2 = ['UK', 'Germany', 'Swiss']
countries_2
# Out:
# ['UK', 'Germany', 'Swiss']

# %%
countries + countries_2
# Out:
# ['Spain',
#  'United States',
#  'India',
#  'Taiwan',
#  'Brazil',
#  'Canada',
#  'UK',
#  'Germany',
#  'Swiss']

# %%
nested_list = [countries, countries_2]
nested_list
# Out:
# [['Spain', 'United States', 'India', 'Taiwan', 'Brazil', 'Canada'],
#  ['UK', 'Germany', 'Swiss']]

# %% [markdown]
# ## 4.2 Removing an elements

# %%
countries = ['United States', 'India', 'Taiwan', 'Brazil']
countries
# Out:
# ['United States', 'India', 'Taiwan', 'Brazil']

# %%
countries.remove('United States')
countries
# Out:
# ['India', 'Taiwan', 'Brazil']

# %%
countries.pop(-1)
countries
# Out:
# ['India', 'Taiwan']

# %%
del countries[0]
countries
# Out:
# ['Taiwan']

# %% [markdown]
# ## 4.3 Sorting a list

# %%
numbers = [4, 3, 10, 9, 8, 2]
numbers
# Out:
# [4, 3, 10, 9, 8, 2]

# %%
numbers.sort()
numbers
# Out:
# [2, 3, 4, 8, 9, 10]

# %%
numbers = [4, 3, 10, 9, 8, 2]
numbers.sort(reverse=True)
numbers
# Out:
# [10, 9, 8, 4, 3, 2]

# %% [markdown]
# ## 4.4 Update an element

# %%
numbers = [4, 3, 10, 9, 8, 2]
numbers
# Out:
# [4, 3, 10, 9, 8, 2]

# %%
numbers[0] = 1000
numbers
# Out:
# [1000, 3, 10, 9, 8, 2]

# %% [markdown]
# ## 4.5 Copying a list

# %%
countries = ['United States', 'India', 'Taiwan', 'Brazil']
new_list = countries[:]
new_list
# Out:
# ['United States', 'India', 'Taiwan', 'Brazil']

# %%
new_list2 = countries.copy()
new_list2
# Out:
# ['United States', 'India', 'Taiwan', 'Brazil']

# %% [markdown]
# # 5 Dictionary

# %%
my_dict = {'key1':'value1', 'key2':'value2'}
my_dict
# Out:
# {'key1': 'value1', 'key2': 'value2'}

# %%
my_data = {'name':'Michael', 'age':63}
my_data
# Out:
# {'name': 'Michael', 'age': 63}

# %%
my_data.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
my_data.values()
# Out:
# dict_values(['Michael', 63])

# %%
my_data.items()
# Out:
# dict_items([('name', 'Michael'), ('age', 63)])

# %%
my_data['height'] = 165
my_data
# Out:
# {'name': 'Michael', 'age': 63, 'height': 165}

# %%
my_data.update({'height':180})
my_data
# Out:
# {'name': 'Michael', 'age': 63, 'height': 180}

# %% [markdown]
# ## 5.1 Copy a dictionary

# %%
my_data = {'name': 'Michael', 'age': 63, 'height': 165}
print(my_data)

new_dict = my_data.copy() # copy by data
print(new_dict)

new_dict2 = my_data # copy by reference
new_dict2
# Out:
# {'name': 'Michael', 'age': 63, 'height': 165}
# {'name': 'Michael', 'age': 63, 'height': 165}
# {'name': 'Michael', 'age': 63, 'height': 165}

# %%
my_data.update({'height':180})
print(my_data)
print(new_dict) # does not affect the other copy of data
new_dict2 # reference to the same copy of data
# Out:
# {'name': 'Michael', 'age': 63, 'height': 180}
# {'name': 'Michael', 'age': 63, 'height': 165}
# {'name': 'Michael', 'age': 63, 'height': 180}

# %% [markdown]
# ## 5.2 Remove an element from dictionary

# %%
my_data = {'name': 'Michael', 'age': 63, 'height': 180}
print(my_data)
my_data.pop('name') # pop by key
my_data
# Out:
# {'name': 'Michael', 'age': 63, 'height': 180}
# {'age': 63, 'height': 180}

# %%
del my_data['age'] # delete by key
my_data
# Out:
# {'height': 180}

# %%
my_data.clear() # remove all elements
my_data
# Out:
# {}

# %% [markdown]
# # 6 If Statement

# %% [markdown]
# if <condition1>:
#     <code1>
# elif <condition2>:
#     <code2>
# ...
#
# else:
#     <code3>

# %%
age = 10

if age >= 18:
    print("You're an adult!")
elif age >= 13:
    print("You're a teenager.")
else:
    print("You're a kid.")
# Out:
# You're a kid.

# %% [markdown]
# # 7 For loop

# %% [markdown]
# for <vaiable> in <iterable>:
#     <code>

# %%
countries = ['United States', 'India', 'Taiwan', 'Brazil']

countries
# Out:
# ['United States', 'India', 'Taiwan', 'Brazil']

# %%
for country in countries:
    print(country)
# Out:
# United States
# India
# Taiwan
# Brazil

# %%
for i, country in enumerate(countries):
    print(i)
    print(country)
# Out:
# 0
# United States
# 1
# India
# 2
# Taiwan
# 3
# Brazil

# %%
my_data = {'name': 'Michael', 'age': 63, 'height': 180}

my_data
# Out:
# {'name': 'Michael', 'age': 63, 'height': 180}

# %%
for key, value in my_data.items():
    print(key)
    print(value)
# Out:
# name
# Michael
# age
# 63
# height
# 180

# %% [markdown]
# # 8 Function
#
# Syntax:
#
#     def function():
#         <code>
#         return

# %%
def add(a, b):
    return a+b

# %%
add(1,3)
# Out:
# 4

# %% [markdown]
# ## 8.1 Built-in Functions

# %%
countries = ['United States', 'India', 'Taiwan', 'Brazil']

countries
# Out:
# ['United States', 'India', 'Taiwan', 'Brazil']

# %%
len(countries)
# Out:
# 4

# %%
max([10,3, 6, 33, 100])
# Out:
# 100

# %%
min([10,3, 6, 33, 100])
# Out:
# 3

# %%
type(countries)
# Out:
# list

# %%
for i in range(1, 10, 2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# # 9 Module

# %% [markdown]
# import

# %% [markdown]
# ## 9.1 OS Module

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/michaelkao/OneDrive/My Projects/Python/Data Analysis'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'Tutorial by Frank.ipynb']

# %%
os.makedirs("New Folder")
os.listdir()
# Out:
# ['New Folder', '.ipynb_checkpoints', 'Tutorial by Frank.ipynb']
